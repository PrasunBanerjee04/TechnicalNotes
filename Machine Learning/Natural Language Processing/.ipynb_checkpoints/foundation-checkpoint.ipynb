# %%
from IPython.display import Image, display, HTML
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Foundations of Natural Language Processing

# %% [markdown]
# Primary problems that NLP aims to solve is the set of methods for making human language accessible to computers, the analysis of a text, generation of context-appropriate text, and in the modern context, accomplishing these tasks by processing fast sums of data and statistical methods. Natural Languages have loose rules of syntax that are ambiguous and not well-defined. Computer Languages are non-natural languages that have well defined syntax and rules of constructions. We first review some prob/stats concepts that are useful for natural language modeling.

# %% [markdown]
# ## Hidden Variables
#
# Recall that for conditional probabilities $P(X|Y) = P(X,Y) / P(X)$. A conditional probability query doesn't always reference all variables in the full distribution. Suppose there are random variables $X, Y, H$. Then the conditional probability formula changes.
#
# $$ P(Y = y|E = e) = \alpha \sum_h P(Y = y, E = e, H = h) $$
#
# Where $\alpha$ is the normalization constant that ensures the probability will sum to zero, and is equal to total probability $P(E = e)$.
#
# $$ \alpha = \frac{1}{\sum_y P(Y = y, E = e)} = \frac{1}{\sum_y \sum_h P(Y = y, E = e, H = h)} $$
#
# For example, suppose I want to figure out $P(Y=1 | E = positive)$, but there's some confounding variable $H$.
#
# 1. Calculate the numerator $\sum_h P(Y = 1, E = positive, H = h)$; we are interested in all worlds where $Y = 1, E = positive$.
# 2. Now to normalize, we need to divide by all cases where $E = positive$, and we do that by dividing by $\sum_y \sum_h P(Y = y, E = positive, H = h)$
#
# If we have multiple hidden variables $H_1, H_2, ... H_n$, we simply do the following.
#
# $$P(Y = y | E = e) = \alpha \sum_{x_1 \in H_1} \sum_{x_2 \in H_2} \dots \sum_{x_n \in H_n} P(Y = y, E = e, H_1 = x_1, \dots, H_n = x_n)$$
# $$\alpha = \frac{1}{P(E = e)} = \frac{1}{\sum_y \sum_{x_1 \in H_1} \sum_{x_2 \in H_2} \dots \sum_{x_n \in H_n} P(Y = y, E = e, H_1 = x_1, \dots, H_n = x_n)}$$

# %% [markdown]
# ## Bayes Rule and Multiple Evidence Variables
#
# For most real world applications, when trying to compute a probability $P(cause | e_1, e_2, \dots e_n)$, we assume the various effects are independent of one another. Recall that $P(A,B) = P(B|A)P(A)$. Similarly, we have that $P(c, e_1, \dots, e_n) = P(c)P(e_1 | c, e_2, \dots e_n)P(e_2 | c, e_1, \dots e_n) \dots P(e_n | c, e_2, \dots e_{n-1})$. However, under the Naive Bayes asssumption, we assume all effects $e_i$ are conditionally independent, so our probability equation reduces to
#
# $$P(c, e_1 \dots e_n) = P(c) P(e_1 | c) P(e_2 | c) \dots P(e_n | c)$$
#
# For example, in a language modeling setting, suppose we wish to figure out (unobservable) if the sentiment of a document is positive, by observing the words $w_1, \dots w_n$ present in them. Based on our naive bayes simplification, we can claim
#
# $$P(+, w_1, \dots, w_n) = P(+) \prod_{i=1}^n P(w_i | +)$$
#
# ### Bayesian Networks
#
# A bayesian network is a useful tool for visualizing and working with complex conditional dependencies. A bayesian network is essentially a directed acyclic graph structure (DAG) wher a node $v_0$ maps to node $v_1$ if $v_1$ is conditionally dependent on $v_0$. Using the bayesian network, we can derive the full joint probability distribution as
#
# $$P(X_1 \dots X_n) = \prod_{i=1}^N P(X_i | \hspace{5px} parents(X_i))$$

# %%
display(Image(filename="bayesNet.png"))

# %% [markdown]
# ## Learning and Neural Networks Overview
#
# Superviesed learning is the problem of learning a function $f$ that maps given inputs to given outputs.

# %%
display(Image(filename="supervised.png"))

# %% [markdown]
# ### Neural Networks
#
# Models a supervised learning task with conected bigraphs and edges with weights/feature importances and nodes representing inputs, outputs, and intermediate computaions based on activation functions. In the network below, the inputs will be passed from layer to layer and produce some $\hat y$ which will then result in some weight adjustment through numerical algorithms intended to reduce the differences between the true value $y$ and the computed $\hat y$.

# %%
display(Image(filename="nn.png"))

# %% [markdown]
# Gradient descent is the process by which we quantify how incorrect the output of the neural network computation is, then update weights to minimize this loss. Suppose some loss function $l(w_1, \dots, w_n)$ quantifies how incorrect $\hat y_i$ is. We compute the gradient of this loss function to determine which direction the loss function decreases the most quickly, and take a step in that direction. We continue this process until convergence. This solves the optmization process of computing the combination of weights that gives us the minimal loss for our model.
#
# $$\nabla L = \frac{ \partial l } { \partial w } = \frac{ \partial (\frac{1}{2} (y - \hat y))^2 } { \partial w } = \frac{ \partial (\frac{1}{2} (y - \sigma(w_i^\text{T}x_i)))^2 } { \partial w }$$
#
# We might update our weights something like $w_1 = w_0 - \eta \nabla L$. Computing gradients can be an expensive operation but modern GPUs parallelize the process by computing parital derivatives for different weights in parallel. See below for a simplified PyTorch implementation of the above neural network with intermediate sigmoid activation functions.

# %%
## sample pytorch implementation 

import torch.nn as nn

class exampleNN(nn.Module):

  def __init__(self):
    super(exampleNN, self).__init__()
    self.linear2 = nn.Linear(4,16)
    self.tanh2 = nn.Tanh()
    self.linear3 = nn.Linear(16,8)
    self.tanh3 = nn.Tanh()
    self.linear4 = nn.Linear(8,2)
    self.tanh4 = nn.Tanh()

  def forward(self, x):
    inter1 = self.linear2(x)
    inter2 = self.tanh2(inter1)
    inter3 = self.linear3(inter2)
    inter4 = self.tanh3(inter3)
    inter5 = self.linear4(inter4)
    y_hat = self.tanh4(inter5)
    return y_hat

# %% [markdown]
# ## Classification Problems
#
# In the context of natural language modeling, classification is the mapping from $V^* \rightarrow \mathcal{L}$ where $V^*$ is the set of all word sequences formed from a vocabulary or word set $V$, and $\mathcal{L}$ is the set of output labels. Some of the important variables and distributions for classification are $X$, the random variable of inputs where each value is some element in $V^*$, $Y$ which is a random variable of outputs taken from $\mathcal{L}$. $P(X,Y)$ is the joint probability distribution of labeled texts (so the probability of observing certain combinations of label and word sequences), and $P(Y)$ which is the distribution of labels irrespective of documents (for example, most financial documents might be negative in sentiment which creates a bias in the data). The problem is that the true distributions of $P(X,Y)$ and $P(Y)$ are typically not known except for labeled data. The process for classification would look something like this.
#
# 1. Construct a set of predictive features $\phi_i$ from the unstructured text data to turn it into structured data
# 2. Feed data into a supervised machine learning algorithm to approximate the function $f: V^* \rightarrow \mathcal{L}$
# 3. Apply $f$ to some proportion of data that is witheld for testing
#
# ### Bag of Words Feature Engineering
#
# For a given document $x$, we can construct a feature set $\phi(x) \in \R^d$ where each element of the vector is 1 if the word is present in the document and 0 otherwise. Another approach might be each element of the vector will be the number of times the word appears in the document. For example, the document containing the sentence "x = I am well" may have a $\phi(x) \in \R^3 = [1, 1, 0, 0, 1]$ where the possible set of words is "I", "am", "sick", "angry", "well". With this vector representation of different documents, we can compute a notion of how "close" one document is to another. We can think of each word as a sort of dimension for our modeling (NLP is generally a very high dimensional problem).
#
# ## Bayesian Classificiation
#
# Suppose we have features $\phi_1 \dots \phi_n$. We know that under the Naive Bayes simplification, we have the following formula, all of which can be computed from the data. In natural language processing, we will often leave out the denominator as it simply scales our answer and does not change anything in a classification context.
#
# $$P(\mathcal{L} | \phi_1 \dots \phi_n) = \frac{P(\phi_1 \dots \phi_n | \mathcal{L})P(\mathcal{L})}{P(\phi_1 \dots \phi_n)} = \frac{P(\phi_1 | \mathcal{L}) \dots P(\phi_n | \mathcal{L})P(\mathcal{L})}{P(\phi_1) \dots P(\phi_n)}$$
#
# We might say the sentiment of a given piece of text is
#
# $$\text{Sentiment} = \text{sign}(P(\mathcal{L}^+ | \phi_1 \dots \phi_n) - P(\mathcal{L}^- | \phi_1 \dots \phi_n))$$
#
# * note that in practical computation, multiplying several probabilities is risky because the product quickly approaches zero. It is often practically beneficial to shift to the log scale as very small values become numerically larger (a very large negative value) and products become additive.

# %% [markdown]
# ## Binary Logistic Classification
#
# Suppose we have outcomes/labels $\mathcal{L} = \{-1, 1\}$. We define the following
#
# $$\text{score}(x, \theta) = \sum_{j=1}^n \theta_j \phi_j(x) = \theta^\text{T} \phi_j(x)$$
# $$\text{classify}(x) = \text{sign}(\text{score}(x, \theta))$$
#
# This is a linear score function. We pass the linear score function through a logistic transformation to make it into a probability. We have a score computed from a linear function of the features, which we then map onto a score in between 0 and 1 using sigmoid.
#
# $$P(Y=y | X=x, \theta) = \sigma(y \times \text{score}(x, \theta))$$
#
# The decision boundary for classification will be the hyperplane that solves the equation $\theta^\text{T} \phi_j(x) = 0$. Then there is a question of parameter estimation. We estimate the parameters through maximum likelihood estimation.
#
# $$\theta^* = \text{arg max}_\theta \prod_{i=1}^n P(Y=y_i | X=x_i, \theta)$$
# $$\theta^* = \text{arg min}_\theta \sum_{i=1}^n -log(P(Y=y_i | X=x_i, \theta))$$
# $$\theta^* = \text{arg min}_\theta \sum_{i=1}^n log(1 + \text{exp}(y_i \theta^\text{T}\phi))$$

# %%
X = np.linspace(-7,7,50)
Y = 1 / (1 + np.exp(-X))
plt.axvline(color='red', linestyle='--')
plt.plot(X,Y)

x1 = np.linspace(-7,7,50)
x2 = np.linspace(-7,7,50)
X1, X2 = np.meshgrid(x1, x2)

w0, w1, w2 = 1, 1, 1
score = w0 + w1*X1 + w2*X2
Z = 1 / (1 + np.exp(-score))

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, Z, cmap='viridis', alpha=0.9)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('P(y=1 | x1, x2)')
ax.set_title('3D Logistic Regression Surface')
plt.show()

# %% [markdown]
# Continuing the example of the optimization above, we know that a given label $y$ can take on values of either zero or one. Note that $P(Y = y | x, \theta) = p(\hat y)$ if $y=1$, and $1-p(\hat y)$ if $y=0$. Note that the logarithms essentially have "confident but wrong" predictions heavily penalized / contribute a lot to the loss function.
#
# ### Loss per sample
#
# $$P(Y = y | x, \theta) = p(\hat y)^y (1 - p(\hat y))^{1-y}$$
# $$log P(Y = y | x, \theta) = y \hspace{3px} \text{log} \hspace{3px} p(\hat y) + (1-y) \hspace{3px} \text{log}(1 - p(\hat y))$$
#
# $$loss(\hat y, y) = -[y \hspace{3px} \text{log} \hspace{3px} p(\hat y) + (1-y) \hspace{3px} \text{log}(1 - p(\hat y))]$$
#
# Our overall loss $L(\theta) = \sum_{i=1}^n loss(y, \hat y)$

# %% [markdown]
# ## Model Training
#
# 1. Initialize Targets
# 2. Split data into batches
# 3. for each batch, compute predictions
# 4. Compute a vector of losses
# 5. Compute gradients and update weights
# 6. Continue 1-5 till all epochs are finished

# %% [markdown]
# ## Multinomial Logistic Classification
